# %% [markdown]
# ## Mallet-TM :
# ### Extract Topic Model with LdaMallet from KCC News and CIS test data

# %%
# -*- coding: utf-8 -*-
"""
Input: "KCC Data/CkipNewsCisTest-KccDict2020.txt"
Output: "KCC Data/NewsCisTest-KccDict2020-MalletNum12.txt"

@author: johnson
"""
# When numpy version = 1.19.2 => gensim version should downgrade to 3.8.3
from gensim import corpora, models, utils
from gensim.models import LdaModel
from gensim.models import CoherenceModel

# %% [markdown]
# ### read data from txt file, and tokenize words, clean-up text

# %%
fList = []
with open("Ly Data/lu_ws.txt","r", encoding='utf-8-sig') as files:
     for file in files:
        #simple_preprocess: tokenize,去除標點 - gensim.utils.simple_preprocess(doc, deacc=False, min_len=2, max_len=15)
        fList.append(list(utils.simple_preprocess(file, deacc=True, min_len=2,)))
print("fList[:2] = ", fList[:2])
print("------------------------------")
# Out:
# fList[:2] =  [['呂委員孫綾', '行政院', '院長', '副院長', '部會', '首長', '同仁', '新北市', '選區', '立法委員', '選區', '包括', '淡水', '三芝', '石門', '八里', '林口', '泰山', '地方', '選區', '發電廠', '請問', '院長', '發電場', '性質', '行政院', '院長', '答復', '張院長善政', '委員', '呂委員孫綾', '電廠', '位於', '性質', '張院長善政', '核能', '電廠', '位在', '金山', '石門', '呂委員孫綾', '張院長善政', '金山', '呂委員孫綾', '金山', '選區', '選區', '林口', '泰山', '淡水', '三芝', '石門', '八里', '張院長善政', '林口', '電廠', '核能', '電廠', '呂委員孫綾', '火力發電廠', '張院長善政', '燃煤', '呂委員孫綾', '發電廠', '居民', '區域', '居民', '影響', '本席', '請教', '二號', '除役', '張院長善政', '經濟部長', '部長', '振中', '核發', '年限', '除役', '呂委員孫綾', '部長', '振中', '主任委員', '源卿', '呂委員孫綾', '號機', '二號機', '除役', '部長', '振中', '原能會', '主委', '指正', '呂委員孫綾', '號機', '二號機', '機會', '提前', '除役', '張院長善政', '目前', '台電', '規劃', '去年', '年底', '送出', '除役', '計畫', '部長', '振中', '對不起', '提前', '除役', '貯存', '料棒', '燃料池', '漸漸', '找不出', '方法', '解決', '外運', '放置', '中期', '貯存槽', '被迫', '除役', '年限', '屆滿', '運轉', '呂委員孫綾', '部長', '面臨', '損害', '變形', '瑕疵', '天災', '災變', '部長', '振中', '說到', '天災', '發生', '運轉', '台電', '注意', '原能會', '監督', '細節', '運作', '嚴密', '計畫', '監督', '呂委員孫綾', '核廢料', '燃料棒', '面臨', '爆滿', '提前', '除役', '提前', '除役', '部長', '振中', '方法', '燃料', '地方', '放置', '呂委員孫綾', '台灣', '禁不起', '災變', '老舊', '核能', '發電廠', '遑論', '石門', '居民', '北北基', '包括', '總統府', '行政院', '立法院', '影響', '機會', '提前', '除役', '政府', '放棄', '請問', '院長', '張院長善政', '除役', '程序', '部長', '提到', '燃料棒', '除役', '提前', '停機', '核子', '工程', '專家', '除役', '停機', '停機', '運轉', '見得', '除役', '程序', '呂委員孫綾', '院長', '提供', '評估', '報告', '張院長善政', '評估', '報告', '呂委員孫綾', '停機', '提前', '除役', '評估', '報告', '張院長善政', '除役', '條件', '停機', '條件', '條件', '原能會', '提供給', '委員', '呂委員孫綾', '院長', 'google', '擔任', '高階', '主管', '院長', 'google', '企業', '文化', '瞭解', '請問', '院長', 'google', '企業', '特色', '張院長善政', '開放', '自由', '鼓勵', '創意', '呂委員孫綾', 'google', '年輕', '員工', '院長', '溝通', '困難', '張院長善政', '還好', '困難', '呂委員孫綾', '年輕人', '溝通', '年齡', '差距', '張院長善政', '年輕人', '呂委員孫綾', '世代', '差距', '年齡', '觀念', '與時俱進', '張院長善政', '年輕人', '相處', '觀念', '開放', '尊重', '態度', '呂委員孫綾', '院長', '相差', '立法院', '國會', '臺灣', '辦法', '展現', '機會', '託付', '國會', '議員', '監督', '政府', '角色', '父執輩', '長輩', '職權', '院長', '質詢', '時代', '改變', '世代', '對話', '張院長善政', '呂委員孫綾', '選舉', '政黨', '國民黨', '空前', '重創', '國會', '少數黨', '評論', '國民黨', '敗選', '報告', '指出', '周子瑜', '事件', '國民黨', '敗選', '主因', '原因', '請問', '院長', '張院長善政', '周子瑜', '事件', '選情', '影響', '呂委員孫綾', '媒體', '評論', '報導', '提出', '詞彙', '天然獨', '院長', '詞彙', '張院長善政', '呂委員孫綾', '請問', '院長', '天然獨', '定義', '張院長善政', '年輕', '成長', '過程', '對岸', '互動', '體認', '臺灣', '獨立', '國家', '獨立', '個體', '想法', '呂委員孫綾', '臺灣', '獨立', '國家', '認同', '張院長善政', '中華民', '國是', '獨立', '主權', '自主', '國家', '臺灣', '呂委員孫綾', '想法', '院長', '天然獨', '概念', '認同', '臺灣', '土地', '深深', '烙印', '自然', '需要', '學習', '東西', '院長', '臺灣', '主權', '獨立', '國家', '烙印', '施政', '臺灣', '優先', '想法', '認同', '張院長善政', '國家', '利益', '優先', '呂委員孫綾', '天然獨', '概念', '世代', '狀態', '政府', '思維', '時俱', '施政', '方向', '扣緊', '時代', '脈動', '地方', '發展', '思維', '時空', '改變', '認同', '張院長善政', '天然獨', '名詞', '政府', '施政', '目標', '過程', '保障', '國家', '利益', '目標', '呂委員孫綾', '院長', '地方', '發展', '建設', '時代', '修正', '改變', '認同', '張院長善政', '與時俱進', '呂委員孫綾', '院長', '選區', '裡面', '都市計畫', '林口', '新市鎮', '淡海', '新市鎮', '第三', '塭仔圳', '重劃區', '都市計畫', '政府', '發展', '地方', '提升', '民眾', '生活品', '規劃', '時空', '變遷', '裡面', '不合時宜', '思維', '檢視', '都市計畫', '內容', '請問', '院長', '說法', '張院長善政', '內容', '與時俱進', '具體', '項目', '需要', '調整', '呂委員孫綾', '院長', '淡海', '新市鎮', '請問', '院長', '淡海', '新市鎮', '計畫', '張院長善政', '內容', '呂委員孫綾', '計畫', '民國', '啟動', '超過', '時間', '都市計畫', '歲數', '新市鎮', '長大', '當初', '淡水', '居民', '期待', '計畫', '帶動', '淡水', '發展', '原本', '計畫', '入住', '淡海', '新市鎮', '歷年來', '審計部', '決算', '審計', '報告', '檢討', '檢討', '報告', '內容', '請問', '院長', '成功', '案例', '張院長善政', '過程', '局面', '內政部', '部長', '威仁', '淡海', '新市鎮', '臺灣', '最早', '開發', '新市鎮', '舒緩', '台北', '都會區', '壓力', '解決', '住宅', '發展', '過程', '包括', '林口', '新市鎮', '事實', '成功', '經濟', '呂委員孫綾', '部長', '淡海', '新市鎮', '成功', '案例', '部長', '威仁', '呂委員孫綾', '院長', '淡海', '新市鎮', '計畫', '規劃', '醫療', '用地', '最近', '檢討', '報告', '變更為', '倉儲用地', '院長', '張院長善政', '內政部', '部長', '威仁', '馬偕', '醫院', '民國', '建議', '淡海', '新市鎮', '裡面', '劃設', '醫療', '專用', '事實', '劃設', '公頃', '醫療', '專用區', '時空', '改變', '長老', '基金會', '呂委員孫綾', '醫療', '專用', '變更為', '倉儲用地', '討論', '部長', '威仁', '公頃', '醫療', '專用區', '原本', '馬偕', '醫院', '分院', '馬 ...
# ------------------------------

# %% [markdown]
# ### creat dictionary for corpus

# %%
# creat a unique id for each word segment
dict = corpora.Dictionary(list(fList))
print("dict = ", dict)
print("------------------------------")
# Out:
# dict =  Dictionary(9855 unique tokens: ['google', '七十多', '三芝', '不利', '不合時宜']...)
# ------------------------------

# %% [markdown]
# ### creat corpus need for Topic Modeling

# %%
# creat mapping matrix of [word_id, word_frequency] for each word segment
corpus = [dict.doc2bow(text) for text in fList]   
print("corpus[:1] = ", corpus[:1])  
print("================================================")

print("print lists of [word:frequency]")
[[print((dict[id], freq)) for id,freq in cp] for cp in corpus[:1]]
print("======================================================")
# Out:
# corpus[:1] =  [[(0, 4), (1, 1), (2, 3), (3, 1), (4, 1), (5, 4), (6, 3), (7, 1), (8, 1), (9, 1), (10, 1), (11, 1), (12, 2), (13, 1), (14, 1), (15, 2), (16, 4), (17, 1), (18, 2), (19, 1), (20, 1), (21, 6), (22, 2), (23, 1), (24, 2), (25, 1), (26, 5), (27, 5), (28, 2), (29, 1), (30, 1), (31, 2), (32, 1), (33, 1), (34, 1), (35, 1), (36, 1), (37, 1), (38, 7), (39, 1), (40, 1), (41, 5), (42, 1), (43, 1), (44, 1), (45, 2), (46, 2), (47, 2), (48, 5), (49, 4), (50, 1), (51, 3), (52, 3), (53, 2), (54, 10), (55, 2), (56, 1), (57, 1), (58, 1), (59, 2), (60, 1), (61, 2), (62, 1), (63, 1), (64, 1), (65, 2), (66, 1), (67, 1), (68, 3), (69, 6), (70, 1), (71, 1), (72, 3), (73, 1), (74, 2), (75, 6), (76, 3), (77, 1), (78, 1), (79, 3), (80, 4), (81, 1), (82, 1), (83, 1), (84, 2), (85, 1), (86, 1), (87, 1), (88, 59), (89, 1), (90, 1), (91, 2), (92, 1), (93, 2), (94, 1), (95, 1), (96, 1), (97, 2), (98, 7), (99, 1), (100, 3), (101, 3), (102, 1), (103, 1), (104, 1), (105, 5), (106, 14), (107, 1), (108, 1), (109, 18), (110, 1), (111, 2), (112, 1), (113, 4), (114, 1), (115, 1), (116, 4), (117, 1), (118, 2), (119, 5), (120, 1), (121, 6), (122, 16), (123, 1), (124, 1), (125, 1), (126, 3), (127, 2), (128, 1), (129, 1), (130, 6), (131, 1), (132, 
# ('長輩', 1)
# ('開放', 2)
# ('開發', 10)
# ('院長', 33)
# ('除役', 16)
# ('集合', 1)
# ('電廠', 4)
# ('需求', 8)
# ('需要', 12)
# ('面向', 1)
# ('面臨', 2)
# ('項目', 1)
# ('順序', 1)
# ('顯示', 1)
# ('飽和', 2)
# ('首長', 1)
# ('馬偕', 4)
# ('體系', 1)
# ('體認', 1)
# ('高公局', 1)
# ('高達', 2)
# ('高階', 1)
# ('鼓勵', 1)
# ======================================================

# %% [markdown]
# ### building the Topic Model from MALLET
# #### enviroment setting for Mallet LDA: https://programminghistorian.org/en/lessons/topic-modeling-and-mallet#installing-mallet

# %%
mallet_path = "/home/deadfate-sky/miniconda3/envs/idp/bin/mallet"
ldamal = models.wrappers.LdaMallet(mallet_path, corpus=corpus, id2word=dict, num_topics=12)
output = open("KCC Data/NewsCisTest-KccDict2020-MalletNum12.txt", 'w', encoding='utf-8-sig')

#print(ldamal.show_topics(formatted=False))
# 列出最重要的前若干个主题
lsTM = ldamal.show_topics(num_topics=12, num_words=20, log=False, formatted=False)
for tupleTM in lsTM:
        str1 = "".join(str(x) for x in tupleTM)
        #print("type(str1) = ", type(str1))
        str1 += "\n"
        print("strTM = ", str1)
        output.write(str1)
output.close()
 
#  print("------------------------------")
#  print("Perplexity = ", ldamal.log_perplexity(corpus))

print("------------------------------")
cm = models.CoherenceModel(model=ldamal, texts=list(fList), dictionary= dict, coherence= 'c_v')
coher_lda = cm.get_coherence()
print("\n Coherence Score: ", coher_lda)
# Out:
# strTM =  0[('委員', 0.04074654509189343), ('中心', 0.020373272545946716), ('關心', 0.017096452486109134), ('包括', 0.01438951417580852), ('目前', 0.014247043738424277), ('同仁', 0.012964809801966092), ('署長', 0.012537398489813363), ('努力', 0.011967516740276393), ('後續', 0.011397634990739421), ('辦理', 0.010970223678586693), ('裡面', 0.010970223678586693), ('需要', 0.010970223678586693), ('部會', 0.010115401054281237), ('想要', 0.009403048867360023), ('方式', 0.009403048867360023), ('預算', 0.009260578429975781), ('政府', 0.009118107992591537), ('國際', 0.008548226243054567), ('環境', 0.007835874056133353), ('衛福部', 0.007550933181364867)]
#
# strTM =  1[('部長', 0.15458358298382266), ('呂委員孫綾', 0.05542240862792091), ('委員', 0.029958058717795086), ('國勇', 0.027112043139604552), ('相關', 0.014230077890952667), ('計畫', 0.013930497303774715), ('文化', 0.012582384661473937), ('同仁', 0.01078490113840623), ('解決', 0.010035949670461354), ('住戶', 0.009286998202516477), ('溝通', 0.009286998202516477), ('預算', 0.009137207908927502), ('本席', 0.008987417615338526), ('經費', 0.008987417615338526), ('協助', 0.008388256440982624), ('地方', 0.00823846614739365), ('歷史', 0.00689035350509287), ('討論', 0.006740563211503895), ('建立', 0.006590772917914919), ('研究', 0.006291192330736968)]
#
#
# ------------------------------
#
#  Coherence Score:  0.4289456780130932

# %% [markdown]
# ### Finding the optimal number of topics

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start, step):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    # global mallet_path, dict
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=num_topics, id2word=dict)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())
        coher = coherencemodel.get_coherence()
        print("Num_topics: ", num_topics, " Coherence Score= ", coher)
    return model_list, coherence_values

# %%
lim=24; sta=3; ste=3;
model_list, coherence_values = compute_coherence_values(dictionary=dict, corpus=corpus, texts=list(fList), limit=lim, start=sta, step=ste)
# Out:
# Num_topics:  3  Coherence Score=  0.37159427035761744
# Num_topics:  6  Coherence Score=  0.4398073626584737
# Num_topics:  9  Coherence Score=  0.455548194981646
# Num_topics:  12  Coherence Score=  0.44167455628456337
# Num_topics:  15  Coherence Score=  0.4344170108470281
# Num_topics:  18  Coherence Score=  0.4328278099244979
# Num_topics:  21  Coherence Score=  0.41231484948267716

# %%
# Show graph
import matplotlib.pyplot as plt

limit=lim; start=sta; step=ste;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
# Print the coherence scores
optNum = 0
maxCV = 0
for m, cv in zip(x, coherence_values):
    # maxCV = lambda cv, maxCV: cv if cv > maxCV else maxCV
    if cv > maxCV:
        optNum = m
        maxCV = cv 
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))
print("Optimal Topic Num =", optNum, " Highest Value =", maxCV)
# Out:
# Num Topics = 3  has Coherence Value of 0.3716
# Num Topics = 6  has Coherence Value of 0.4398
# Num Topics = 9  has Coherence Value of 0.4555
# Num Topics = 12  has Coherence Value of 0.4417
# Num Topics = 15  has Coherence Value of 0.4344
# Num Topics = 18  has Coherence Value of 0.4328
# Num Topics = 21  has Coherence Value of 0.4123
# Optimal Topic Num = 9  Highest Value = 0.455548194981646

# %% [markdown]
# ###  Select the model and print the topics

# %%
len(model_list)
# Out:
# 7

# %%
from pprint import pprint

optimal_model = model_list[6]
# model_topics = optimal_model.show_topics(formatted=False)
pprint(optimal_model.print_topics(num_words=20))
# Out:
# [(19,
#   '0.029*"呂委員孫綾" + 0.029*"發生" + 0.025*"訊息" + 0.020*"狀況" + 0.019*"系統" + '
#   '0.016*"國人" + 0.015*"有沒有" + 0.012*"測試" + 0.012*"聯繫" + 0.012*"災害" + '
#   '0.012*"地方" + 0.011*"影響" + 0.011*"政府" + 0.011*"消息" + 0.011*"防災" + 0.010*"委員" '
#   '+ 0.010*"台灣" + 0.010*"建立" + 0.010*"需要" + 0.009*"時間"'),
#  (5,
#   '0.060*"部長" + 0.049*"國軍" + 0.035*"國防部" + 0.032*"呂委員孫綾" + 0.024*"世寬" + '
#   '0.021*"委員" + 0.020*"官兵" + 0.020*"女性" + 0.014*"德發" + 0.012*"部隊" + 0.010*"訓練" '
#   '+ 0.010*"營區" + 0.009*"機制" + 0.009*"弟兄" + 0.008*"軍官" + 0.008*"募兵制" + '
#   '0.007*"學生" + 0.007*"軍事" + 0.006*"軍人" + 0.006*"提到"'),
#  (4,
#   '0.070*"委員長" + 0.036*"僑委會" + 0.029*"新興" + 0.027*"海外" + 0.023*"呂委員孫綾" + '
#   '0.022*"僑胞" + 0.021*"委員" + 0.021*"服務" + 0.016*"台商" + 0.013*"台灣" + 0.012*"成立" '
#   '+ 0.012*"僑界" + 0.010*"僑務" + 0.010*"臺灣" + 0.010*"僑校" + 0.008*"副委員長" + '
#   '0.008*"組織" + 0.008*"國家" + 0.008*"中心" + 0.008*"協助"'),
#  (7,
#   '0.042*"醫療" + 0.029*"需要" + 0.020*"資源" + 0.020*"檢討" + 0.018*"提供" + 0.017*"委員" '
#   '+ 0.016*"需求" + 0.014*"政府" + 0.013*"努力" + 0.012*"醫院" + 0.011*"思考" + '
#   '0.011*"社會" + 0.010*"納入" + 0.009*"目標" + 0.009*"民眾" + 0.009*"民主" + 0.009*"衛生" '
#   '+ 0.008*"臺灣" + 0.008*"衛福部" + 0.008*"政策"'),
#  (13,
#   '0.038*"呂委員孫綾" + 0.030*"國家" + 0.024*"語言" + 0.024*"目前" + 0.020*"東南亞" + '
#   '0.018*"南向政策" + 0.018*"推動" + 0.018*"處長" + 0.016*"外交部" + 0.015*"觀光" + '
#   '0.015*"人才" + 0.015*"開放" + 0.014*"委員" + 0.013*"越南" + 0.012*"本席" + 0.012*"政府" '
#   '+ 0.011*"外交" + 0.011*"努力" + 0.010*"菲律賓" + 0.010*"人數"'),
#  (2,
#   '0.058*"主委" + 0.038*"退輔會" + 0.038*"主任委員" + 0.036*"呂委員孫綾" + 0.023*"榮民" + '
#   '0.022*"處長" + 0.020*"服務" + 0.019*"榮家" + 0.016*"翔宙" + 0.014*"委員" + 0.012*"長照" '
#   '+ 0.012*"網站" + 0.012*"床位" + 0.010*"照顧" + 0.010*"民眾" + 0.009*"榮總" + '
#   '0.008*"資源" + 0.008*"資訊" + 0.008*"提供" + 0.008*"持股"'),
#  (12,
#   '0.024*"青年" + 0.022*"學校" + 0.022*"臺灣" + 0.021*"活動" + 0.018*"努力" + '
#   '0.018*"教育部" + 0.017*"方式" + 0.014*"舉辦" + 0.011*"宣傳" + 0.011*"呂委員孫綾" + '
#   '0.011*"地區" + 0.010*"教育" + 0.010*"目前" + 0.010*"打工" + 0.010*"學生" + 0.010*"交流" '
#   '+ 0.009*"規劃" + 0.009*"提供" + 0.009*"度假" + 0.009*"文宣"'),
#  (18,
#   '0.049*"副部長" + 0.042*"國防部" + 0.032*"呂委員孫綾" + 0.029*"國防" + 0.027*"委員" + '
#   '0.017*"海軍" + 0.014*"網路" + 0.014*"參謀長" + 0.014*"答復" + 0.014*"廠商" + '
#   '0.011*"時間" + 0.011*"本席" + 0.010*"局長" + 0.010*"相關" + 0.010*"案子" + 0.010*"信心" '
#   '+ 0.009*"作戰" + 0.008*"演習" + 0.008*"完成" + 0.008*"單位"'),
#  (6,
#   '0.044*"院長" + 0.029*"地方" + 0.023*"部長" + 0.022*"交通" + 0.021*"新市鎮" + '
#   '0.020*"淡海" + 0.017*"建設" + 0.016*"呂委員孫綾" + 0.016*"淡水" + 0.016*"地區" + '
#   '0.015*"居民" + 0.014*"計畫" + 0.014*"市政府" + 0.014*"淡江" + 0.014*"交通部" + '
#   '0.013*"八里" + 0.012*"規劃" + 0.011*"新北" + 0.011*"開發" + 0.011*"北海岸"'),
#  (0,
#   '0.155*"部長" + 0.062*"呂委員孫綾" + 0.051*"國勇" + 0.033*"委員" + 0.021*"本席" + '
#   '0.020*"署長" + 0.015*"相關" + 0.013*"同仁" + 0.012*"內政部" + 0.011*"提到" + '
#   '0.010*"地方" + 0.009*"教部" + 0.008*"建議" + 0.008*"程度" + 0.008*"裡面" + 0.007*"警察" '
#   '+ 0.007*"討論" + 0.006*"管制" + 0.006*"研議" + 0.006*"明確"'),
#  (14,
#   '0.045*"發展" + 0.036*"目前" + 0.033*"產業" + 0.032*"合作" + 0.020*"國防" + 0.019*"經濟" '
#   '+ 0.019*"計畫" + 0.016*"提到" + 0.016*"推動" + 0.016*"國家" + 0.013*"政策" + '
#   '0.011*"民間" + 0.011*"技術" + 0.010*"工業" + 0.010*"國際" + 0.009*"努力" + 0.009*"規劃" '
#   '+ 0.009*"能量" + 0.009*"國外" + 0.009*"委員"'),
#  (1,
#   '0.032*"委員" + 0.030*"中心" + 0.026*"社會住宅" + 0.026*"林口" + 0.021*"呂委員孫綾" + '
#   '0.020*"住戶" + 0.017*"溝通" + 0.013*"管理" + 0.012*"解決" + 0.012*"內政部" + '
#   '0.011*"選手村" + 0.010*"社會" + 0.009*"國際" + 0.009*"原住民" + 0.009*"剛剛" + '
#   '0.009*"包括" + 0.009*"比例" + 0.009*"世大運" + 0.009*"完成" + 0.009*"建置"'),
#  (17,
#   '0.035*"狀況" + 0.029*"委員" + 0.027*"投票" + 0.022*"呂委員孫綾" + 0.022*"發生" + '
#   '0.022*"方式" + 0.019*"人員" + 0.012*"選舉" + 0.011*"實施" + 0.011*"媒體" + 0.011*"工作" '
#   '+ 0.010*"民眾" + 0.010*"中選會" + 0.010*"陪同" + 0.010*"時間" + 0.009*"代理" + '
#   '0.009*"提醒" + 0.009*"毒品" + 0.009*"剛剛" + 0.008*"處長"'),
#  (16,
#   '0.038*"呂委員孫綾" + 0.027*"文化" + 0.027*"計畫" + 0.025*"委員" + 0.024*"預算" + '
#   '0.017*"部長" + 0.016*"目前" + 0.014*"經費" + 0.014*"研究" + 0.014*"處長" + 0.013*"歷史" '
#   '+ 0.013*"相關" + 0.012*"年度" + 0.011*"保存" + 0.011*"報告" + 0.010*"單位" + '
#   '0.010*"裡面" + 0.010*"成立" + 0.009*"國防部" + 0.009*"資料"'),
#  (15,
#   '0.065*"呂委員孫綾" + 0.059*"局長" + 0.020*"國安局" + 0.019*"委員" + 0.016*"國家" + '
#   '0.016*"高部長" + 0.016*"報告" + 0.015*"副局長" + 0.015*"相關" + 0.015*"廣圻" + '
#   '0.012*"單位" + 0.012*"情資" + 0.011*"調查" + 0.011*"國強" + 0.011*"有沒有" + '
#   '0.009*"蒐集" + 0.009*"情報" + 0.009*"勝竹" + 0.008*"機關" + 0.008*"資訊"'),
#  (8,
#   '0.095*"部長" + 0.043*"外交部" + 0.036*"國家" + 0.032*"呂委員孫綾" + 0.027*"大維" + '
#   '0.027*"外交" + 0.023*"努力" + 0.020*"臺灣" + 0.018*"委員" + 0.016*"美國" + 0.016*"總統" '
#   '+ 0.015*"國際" + 0.014*"釗燮" + 0.013*"台灣" + 0.012*"加入" + 0.010*"支持" + '
#   '0.010*"合作" + 0.008*"同仁" + 0.008*"參與" + 0.008*"組織"'),
#  (3,
#   '0.040*"呂委員孫綾" + 0.027*"本席" + 0.018*"請教" + 0.017*"協助" + 0.015*"提到" + '
#   '0.014*"客家" + 0.012*"提供" + 0.012*"副署長" + 0.012*"組長" + 0.011*"漁民" + '
#   '0.011*"明確" + 0.011*"會議" + 0.010*"政府" + 0.009*"提出" + 0.009*"評估" + 0.009*"漁會" '
#   '+ 0.008*"包括" + 0.008*"研究" + 0.008*"報告" + 0.008*"宣導"'),
#  (10,
#   '0.168*"次長" + 0.027*"目前" + 0.026*"呂委員孫綾" + 0.019*"國家" + 0.015*"措施" + '
#   '0.013*"機制" + 0.012*"請教" + 0.012*"公司" + 0.011*"投資" + 0.010*"透過" + 0.009*"委員" '
#   '+ 0.009*"本席" + 0.009*"辦法" + 0.008*"相關" + 0.008*"法案" + 0.008*"版本" + '
#   '0.008*"德立" + 0.007*"採購" + 0.007*"因應" + 0.007*"官員"'),
#  (9,
#   '0.029*"提出" + 0.028*"相關" + 0.026*"報告" + 0.022*"目前" + 0.021*"狀況" + 0.019*"政府" '
#   '+ 0.018*"委員" + 0.018*"辦法" + 0.016*"意見" + 0.016*"行政院" + 0.014*"單位" + '
#   '0.014*"過程" + 0.013*"事實" + 0.013*"執行" + 0.012*"方向" + 0.012*"內容" + 0.012*"瞭解" '
#   '+ 0.011*"包括" + 0.010*"部會" + 0.010*"協調"'),
#  (11,
#   '0.041*"呂委員孫綾" + 0.028*"同仁" + 0.026*"人員" + 0.018*"工作" + 0.016*"制度" + '
#   '0.013*"軍人" + 0.013*"主任委員" + 0.013*"請問" + 0.012*"退伍" + 0.011*"方向" + '
#   '0.011*"意見" + 0.011*"溝通" + 0.010*"委員" + 0.010*"預算" + 0.010*"海巡署" + '
#   '0.009*"草案" + 0.009*"專長" + 0.009*"主委" + 0.009*"仲威" + 0.009*"原因"')]

# %%
with open('lu_LDA.txt', 'w') as out:
    pprint(optimal_model.print_topics(num_words=20), stream=out)
